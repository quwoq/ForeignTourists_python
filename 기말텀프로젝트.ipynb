# %%
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.font_manager as fm #한글 폰트 사용하기 위한 라이브러리

# %%
# %matplotlib nbagg

# %%
df = pd.read_csv("china.txt", delimiter="\t")

# %%
df.head() #수집한 파일의 데이터프레임
# Out:
#         기간      구분 국적별외국인 관광객 국적별외국인 관광객.1 국적별외국인 관광객.2 국적별외국인 관광객.3  \
# 0       기간      구분         합계           합계           합계           일본
# 1       기간      구분          계           남자           여자            계
# 2  2019.03  방문 외국인  1,535,641      576,167      876,370      375,119
# 3  2019.04  방문 외국인  1,635,066      628,813      907,761      290,092
# 4  2019.05  방문 외국인  1,485,684      578,778      809,257      286,273
#
#   국적별외국인 관광객.4 국적별외국인 관광객.5 국적별외국인 관광객.6 국적별외국인 관광객.7 국적별외국인 관광객.8  \
# 0           일본           일본           미국           미국           미국
# 1           남자           여자            계           남자           여자
# 2      106,174      266,368       84,275       43,129       35,984
# 3      106,567      180,586      102,524       50,350       46,617
# 4      104,270      179,372       95,815       47,995       41,970
#
#   국적별외국인 관광객.9 국적별외국인 관광객.10 국적별외국인 관광객.11 국적별외국인 관광객.12 국적별외국인 관광객.13  \
# 0           중국            중국            중국          해외동포          해외동포
# 1            계            남자            여자             계            남자
# 2      487,623       189,613       285,340        19,225         7,845
# 3      493,250       180,816       298,870        20,174         8,255
# 4      500,413       187,922       297,661        18,788         7,694
#
#   국적별외국인 관광객.14 국적별외국인 관광객.15 국적별외국인 관광객.16 국적별외국인 관광객.17
# 0          해외동포            기타            기타            기타
# 1            여자             계            남자            여자
# 2        11,380       569,399       229,406       277,298
# 3        11,919       729,026       282,825       369,769
# 4        11,094       584,395       230,897       279,160

# %%
df.columns
# Out:
# Index(['기간', '구분', '국적별외국인 관광객', '국적별외국인 관광객.1', '국적별외국인 관광객.2',
#        '국적별외국인 관광객.3', '국적별외국인 관광객.4', '국적별외국인 관광객.5', '국적별외국인 관광객.6',
#        '국적별외국인 관광객.7', '국적별외국인 관광객.8', '국적별외국인 관광객.9', '국적별외국인 관광객.10',
#        '국적별외국인 관광객.11', '국적별외국인 관광객.12', '국적별외국인 관광객.13', '국적별외국인 관광객.14',
#        '국적별외국인 관광객.15', '국적별외국인 관광객.16', '국적별외국인 관광객.17'],
#       dtype='object')

# %%
df = df.rename(columns={'국적별외국인 관광객.9': '중국 합계','국적별외국인 관광객.10': '중국인 남성', '국적별외국인 관광객.11': '중국인 여성'})

# %%
df = df.rename(columns={'국적별외국인 관광객.3': '일본 합계','국적별외국인 관광객.4': '일본인 남성', '국적별외국인 관광객.5': '일본인 여성'})

# %%
df = df.rename(columns={'국적별외국인 관광객.6': '미국 합계','국적별외국인 관광객.7': '미국인 남성', '국적별외국인 관광객.8': '미국인 여성'})

# %%
df.head()
# Out:
#         기간      구분 국적별외국인 관광객 국적별외국인 관광객.1 국적별외국인 관광객.2    일본 합계   일본인 남성  \
# 0       기간      구분         합계           합계           합계       일본       일본
# 1       기간      구분          계           남자           여자        계       남자
# 2  2019.03  방문 외국인  1,535,641      576,167      876,370  375,119  106,174
# 3  2019.04  방문 외국인  1,635,066      628,813      907,761  290,092  106,567
# 4  2019.05  방문 외국인  1,485,684      578,778      809,257  286,273  104,270
#
#     일본인 여성    미국 합계  미국인 남성  미국인 여성    중국 합계   중국인 남성   중국인 여성 국적별외국인 관광객.12  \
# 0       일본       미국      미국      미국       중국       중국       중국          해외동포
# 1       여자        계      남자      여자        계       남자       여자             계
# 2  266,368   84,275  43,129  35,984  487,623  189,613  285,340        19,225
# 3  180,586  102,524  50,350  46,617  493,250  180,816  298,870        20,174
# 4  179,372   95,815  47,995  41,970  500,413  187,922  297,661        18,788
#
#   국적별외국인 관광객.13 국적별외국인 관광객.14 국적별외국인 관광객.15 국적별외국인 관광객.16 국적별외국인 관광객.17
# 0          해외동포          해외동포            기타            기타            기타
# 1            남자            여자             계            남자            여자
# 2         7,845        11,380       569,399       229,406       277,298
# 3         8,255        11,919       729,026       282,825       369,769
# 4         7,694        11,094       584,395       230,897       279,160

# %%
df1 = df.drop([0,1])

# %%
df1.index=['19.03','19.04','19.05','19.06','19.07','19.08','19.09','19.10','19.11','19.12','20.01','20.02','20.03']

# %%
df1.head(2)
# Out:
#             기간      구분 국적별외국인 관광객 국적별외국인 관광객.1 국적별외국인 관광객.2    일본 합계   일본인 남성  \
# 19.03  2019.03  방문 외국인  1,535,641      576,167      876,370  375,119  106,174
# 19.04  2019.04  방문 외국인  1,635,066      628,813      907,761  290,092  106,567
#
#         일본인 여성    미국 합계  미국인 남성  미국인 여성    중국 합계   중국인 남성   중국인 여성  \
# 19.03  266,368   84,275  43,129  35,984  487,623  189,613  285,340
# 19.04  180,586  102,524  50,350  46,617  493,250  180,816  298,870
#
#       국적별외국인 관광객.12 국적별외국인 관광객.13 국적별외국인 관광객.14 국적별외국인 관광객.15 국적별외국인 관광객.16  \
# 19.03        19,225         7,845        11,380       569,399       229,406
# 19.04        20,174         8,255        11,919       729,026       282,825
#
#       국적별외국인 관광객.17
# 19.03       277,298
# 19.04       369,769

# %%
data1 = df1.loc[:,['중국인 남성','중국인 여성','중국 합계']]

# %%
data2 = df1.loc[:,['일본인 남성','일본인 여성','일본 합계']]

# %%
data3 = df1.loc[:,['미국인 남성','미국인 여성','미국 합계']]

# %%
data1
# Out:
#         중국인 남성   중국인 여성    중국 합계
# 19.03  189,613  285,340  487,623
# 19.04  180,816  298,870  493,250
# 19.05  187,922  297,661  500,413
# 19.06  169,793  292,378  475,007
# 19.07  186,367  319,475  519,132
# 19.08  216,737  345,329  578,112
# 19.09  198,669  330,432  541,350
# 19.10  204,531  348,980  567,695
# 19.11  183,200  310,161  505,369
# 19.12  179,833  315,451  508,877
# 20.01  179,530  289,862  481,681
# 20.02   52,686   48,043  104,086
# 20.03    7,734    8,300   16,595

# %%
data2
# Out:
#         일본인 남성   일본인 여성    일본 합계
# 19.03  106,174  266,368  375,119
# 19.04  106,567  180,586  290,092
# 19.05  104,270  179,372  286,273
# 19.06   98,280  181,523  282,476
# 19.07   95,905  176,508  274,830
# 19.08  113,714  212,982  329,652
# 19.09   89,993  158,395  251,119
# 19.10   86,539  159,473  248,541
# 19.11   88,718  167,326  258,522
# 19.12   89,354  163,795  255,356
# 20.01   71,921  129,621  203,969
# 20.02   67,646  141,475  211,199
# 20.03    3,079    4,943    8,347

# %%
data3
# Out:
#        미국인 남성  미국인 여성    미국 합계
# 19.03  43,129  35,984   84,275
# 19.04  50,350  46,617  102,524
# 19.05  47,995  41,970   95,815
# 19.06  52,374  47,515  105,398
# 19.07  47,919  43,696   97,428
# 19.08  43,314  37,094   86,586
# 19.09  45,746  39,440   90,819
# 19.10  50,361  44,870  101,099
# 19.11  43,218  33,919   82,238
# 19.12  40,446  32,327   77,387
# 20.01  33,394  27,487   67,255
# 20.02  20,570  16,333   42,439
# 20.03   4,178   3,360   10,570

# %%
data1['중국인 남성'] =data1['중국인 남성'].str.replace(",","").astype("float")
data1['중국인 여성'] =data1['중국인 여성'].str.replace(",","").astype("float")
data1['중국 합계'] =data1['중국 합계'].str.replace(",","").astype("float")

# %%
data1.head(2)
# Out:
#          중국인 남성    중국인 여성     중국 합계
# 19.03  189613.0  285340.0  487623.0
# 19.04  180816.0  298870.0  493250.0

# %%
data2['일본인 남성'] =data2['일본인 남성'].str.replace(",","").astype("float")
data2['일본인 여성'] =data2['일본인 여성'].str.replace(",","").astype("float")
data2['일본 합계'] =data2['일본 합계'].str.replace(",","").astype("float")

# %%
data3['미국인 남성'] =data3['미국인 남성'].str.replace(",","").astype("float")
data3['미국인 여성'] =data3['미국인 여성'].str.replace(",","").astype("float")
data3['미국 합계'] =data3['미국 합계'].str.replace(",","").astype("float")

# %%
fm.get_fontconfig_fonts()
font_location = 'C:/Windows/Fonts/HANDotum.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
matplotlib.rc('font', family=font_name)
## title, label 등에 한글을 사용하기 위함

# %%
"""
ax = plt.subplot(111)
ax.bar(np.arange(len(data1.index))-0.2, data1['중국인 남성'], width=0.2, color='b', align='center',label='male')
ax.bar(np.arange(len(data1.index)), data1['중국인 여성'], width=0.2, color='r', align='center',label='female')
ax.bar(np.arange(len(data1.index))+0.2, data1['중국 합계'], width=0.2, color='g', align='center',label='total')
plt.legend()
plt.xticks(np.arange(len(data1.index)),data1.index,rotation=30)
plt.xlabel("기간")
plt.title("중국인 방문객 현황")

plt.show()
"""
# Out:
# '\nax = plt.subplot(111)\nax.bar(np.arange(len(data1.index))-0.2, data1[\'중국인 남성\'], width=0.2, color=\'b\', align=\'center\',label=\'male\')\nax.bar(np.arange(len(data1.index)), data1[\'중국인 여성\'], width=0.2, color=\'r\', align=\'center\',label=\'female\')\nax.bar(np.arange(len(data1.index))+0.2, data1[\'중국 합계\'], width=0.2, color=\'g\', align=\'center\',label=\'total\')\nplt.legend()\nplt.xticks(np.arange(len(data1.index)),data1.index,rotation=30)\nplt.xlabel("기간")\nplt.title("중국인 방문객 현황")\n\nplt.show()\n'

# %%
"""
ax = plt.subplot(111)
ax.bar(np.arange(len(data2.index))-0.2, data2['일본인 남성'], width=0.2, color='olive', align='center',label='male')
ax.bar(np.arange(len(data2.index)), data2['일본인 여성'], width=0.2, color='pink', align='center',label='female')
ax.bar(np.arange(len(data2.index))+0.2, data2['일본 합계'], width=0.2, color='yellow', align='center',label='total')
plt.legend()
plt.xticks(np.arange(len(data2.index)),data2.index,rotation=30)
plt.xlabel("기간")
plt.title("일본인 방문객 현황")

plt.show()
"""
# Out:
# '\nax = plt.subplot(111)\nax.bar(np.arange(len(data2.index))-0.2, data2[\'일본인 남성\'], width=0.2, color=\'olive\', align=\'center\',label=\'male\')\nax.bar(np.arange(len(data2.index)), data2[\'일본인 여성\'], width=0.2, color=\'pink\', align=\'center\',label=\'female\')\nax.bar(np.arange(len(data2.index))+0.2, data2[\'일본 합계\'], width=0.2, color=\'yellow\', align=\'center\',label=\'total\')\nplt.legend()\nplt.xticks(np.arange(len(data2.index)),data2.index,rotation=30)\nplt.xlabel("기간")\nplt.title("일본인 방문객 현황")\n\nplt.show()\n'

# %%
ax = plt.subplot(111)
ax.bar(np.arange(len(data3.index))-0.2, data3['미국인 남성'], width=0.2, color='chocolate', align='center',label='male')
ax.bar(np.arange(len(data3.index)), data3['미국인 여성'], width=0.2, color='c', align='center',label='female')
ax.bar(np.arange(len(data3.index))+0.2, data3['미국 합계'], width=0.2, color='brown', align='center',label='total')
plt.legend()
plt.xticks(np.arange(len(data3.index)),data3.index,rotation=30)
plt.xlabel("기간")
plt.title("미국인 방문객 현황")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
df1.to_csv("방문객_통계.csv")
